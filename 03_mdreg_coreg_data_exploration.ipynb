# %% [markdown]
# Hier wird eine Exploration der entstandenen Daten aus der mdreg-coreg Erzeugung der DCE Daten durchgeführt.

# %%
import dask.array as da

# %% [markdown]
# Laden der zarr-Dateien.

# %%
fit_darr = da.from_zarr('/media/shooty/Dev/repos/MRI-MoCoCo/MRI-Datasets/mdreg_DCE_fitting_results/fit_zarr_2.zarr')
fit_darr
# Out:
# dask.array<from-zarr, shape=(256, 256, 50, 1000), dtype=float32, chunksize=(256, 256, 1, 1), chunktype=numpy.ndarray>

# %%
pars_darr = da.from_zarr('/media/shooty/Dev/repos/MRI-MoCoCo/MRI-Datasets/mdreg_DCE_fitting_results/pars_zarr_2.zarr')
pars_darr
# Out:
# dask.array<from-zarr, shape=(256, 256, 50, 4), dtype=float32, chunksize=(256, 256, 1, 4), chunktype=numpy.ndarray>

# %%
transfo_darr = da.from_zarr('/media/shooty/Dev/repos/MRI-MoCoCo/MRI-Datasets/mdreg_DCE_fitting_results/transfo_zarr_2.zarr')
transfo_darr
# Out:
# dask.array<from-zarr, shape=(256, 256, 50, 1000, 3), dtype=float32, chunksize=(256, 256, 1, 1, 3), chunktype=numpy.ndarray>

# %%
coreg_darr = da.from_zarr('/media/shooty/Dev/repos/MRI-MoCoCo/MRI-Datasets/mdreg_DCE_fitting_results/coreg_zarr_2.zarr')
coreg_darr
# Out:
# dask.array<from-zarr, shape=(256, 256, 50, 1000), dtype=float32, chunksize=(256, 256, 1, 1), chunktype=numpy.ndarray>

# %% [markdown]
# Laden in Arbeitsspeicher und transformieren.

# %%
import numpy as np

# %%
fit = fit_darr[:,:,27,:].compute()
fit = np.transpose(fit, [2,1,0])

# %% [markdown]
# Laden der DCE Daten

# %%
raw_darr = da.from_zarr('/media/shooty/Dev/repos/MRI-MoCoCo/MRI-Datasets/DCE')
raw_darr
# Out:
# dask.array<from-zarr, shape=(256, 256, 50, 1000), dtype=float32, chunksize=(256, 256, 1, 1), chunktype=numpy.ndarray>

# %%
raw = raw_darr[:,:,27,:].compute()
raw = np.transpose(raw, [2,1,0])

# %% [markdown]
# Darstellung der Aufnahmen und verabeiteten Bilder.

# %%
import helpers

# %%
helpers.explore_3D_array_comparison(raw, fit)
# Out:
# interactive(children=(IntSlider(value=499, description='SLICE', max=999), Output()), _dom_classes=('widget-int…

# %%
pars = pars_darr[:,:,:,0].compute()
pars = np.transpose(pars,[2,1,0])

# %%
helpers.explore_3D_array(pars)
# Out:
# interactive(children=(IntSlider(value=24, description='SLICE', max=49), Output()), _dom_classes=('widget-inter…

# %%
transfo = transfo_darr[:,:,27,:,2]
transfo = np.transpose(transfo, [2,1,0])

# %%
helpers.explore_3D_array(transfo)
# Out:
# interactive(children=(IntSlider(value=499, description='SLICE', max=999), Output()), _dom_classes=('widget-int…

# %%
coreg = coreg_darr[:,:,27,:].compute()
coreg = np.transpose(coreg, [2,1,0])

# %%
helpers.explore_3D_array_comparison(raw,coreg)
# Out:
# interactive(children=(IntSlider(value=499, description='SLICE', max=999), Output()), _dom_classes=('widget-int…
